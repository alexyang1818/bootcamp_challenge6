# %%
import random

lats = []
lngs = []
for i in range(2000):
    lats.append(random.randint(-90, 89) + random.random())
    lngs.append(random.randint(-180,179) + random.random())

lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
from citipy import citipy

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1])
    if city not in cities:
        cities.append(city)

# for city in cities:
#     print(f'{city.city_name}, {city.country_code}')
print(len(cities))
# Out:
# 767

# %%
import requests
import json
from config import openweather_key

openweather_url = 'http://api.openweathermap.org/data/2.5/weather?units=imperial&' # ?q=London,uk&appid={API key}'
weather_list = []

for city in cities:
    city_country = city.city_name + ',' + city.country_code
    url = openweather_url + f'q={city_country}&appid={openweather_key}'
    
    try:
        response = requests.get(url).json()
        # print(json.dumps(response,indent=4))
        city_lat = response['coord']['lat']
        city_lng = response['coord']['lon']
        city_name = response['name']
        country = response['sys']['country']
        max_temp = response['main']['temp_max']
        humidity = response['main']['humidity']
        cloudiness = response['clouds']['all']
        wind_speed = response['wind']['speed']
        description = response['weather'][0]['description']
    except:
        print(f'{city_country} not found. Skipping...')
        continue

    current_weather = {
        'City': city_name,
        'Country': country,
        'Lat': city_lat,
        'Lng': city_lng,
        'Max Temp (F)': max_temp,
        'Humidity (%)':humidity,
        'Cloudiness (%)':cloudiness,
        'Wind Speed (mph)': wind_speed,
        'Current Description': description
    }

    weather_list.append(current_weather)

print(len(weather_list))
# Out:
# mataura,pf not found. Skipping...
# barentsburg,sj not found. Skipping...
# sentyabrskiy,ru not found. Skipping...
# nizhneyansk,ru not found. Skipping...
# illoqqortoormiut,gl not found. Skipping...
# tumannyy,ru not found. Skipping...
# airai,pw not found. Skipping...
# cagayan de tawi-tawi,ph not found. Skipping...
# tsihombe,mg not found. Skipping...
# buariki,ki not found. Skipping...
# taolanaro,mg not found. Skipping...
# belushya guba,ru not found. Skipping...
# grand river south east,mu not found. Skipping...
# samusu,ws not found. Skipping...
# bereda,so not found. Skipping...
# ngukurr,au not found. Skipping...
# kamenskoye,ru not found. Skipping...
# sofiysk,ru not found. Skipping...
# bolungarvik,is not found. Skipping...
# stoyba,ru not found. Skipping...
# saleilua,ws not found. Skipping...
# tvardica,bg not found. Skipping...
# faya,td not found. Skipping...
# tabiauea,ki not found. Skipping...
# meyungs,pw not found. Skipping...
# lokken verk,no not found. Skipping...
# saint anthony,ca not found. Skipping...
# avera,pf not found. Skipping...
# tasbuget,kz not found. Skipping...
# codrington,ag not found. Skipping...
# pousat,kh not found. Skipping...
# gogrial,sd not found. Skipping...
# aflu,dz not found. Skipping...
# saleaula,ws not found. Skipping...
# vila,vu not found. Skipping...
# udala,in not found. Skipping...
# attawapiskat,ca not found. Skipping...
# amderma,ru not found. Skipping...
# rungata,ki not found. Skipping...
# mys shmidta,ru not found. Skipping...
# tubruq,ly not found. Skipping...
# burica,pa not found. Skipping...
# palabuhanratu,id not found. Skipping...
# louisbourg,ca not found. Skipping...
# abu samrah,qa not found. Skipping...
# lata,sb not found. Skipping...
# malwan,in not found. Skipping...
# wampusirpi,hn not found. Skipping...
# buin,pg not found. Skipping...
# satitoa,ws not found. Skipping...
# mentok,id not found. Skipping...
# tonj,sd not found. Skipping...
# cuilapam,mx not found. Skipping...
# kneza,bg not found. Skipping...
# nguiu,au not found. Skipping...
# mata,cn not found. Skipping...
# vaitupu,wf not found. Skipping...
# artyk,ru not found. Skipping...
# karauzyak,uz not found. Skipping...
# marcona,pe not found. Skipping...
# tarudant,ma not found. Skipping...
# gat,ly not found. Skipping...
# sorvag,fo not found. Skipping...
# doha,kw not found. Skipping...
# japura,br not found. Skipping...
# inderborskiy,kz not found. Skipping...
# umzimvubu,za not found. Skipping...
# sinkat,sd not found. Skipping...
# asau,tv not found. Skipping...
# shibarghan,af not found. Skipping...
# kachikau,bw not found. Skipping...
# sataua,ws not found. Skipping...
# lolua,tv not found. Skipping...
# ruatoria,nz not found. Skipping...
# toliary,mg not found. Skipping...
# kralendijk,an not found. Skipping...
# buon me thuot,vn not found. Skipping...
# viligili,mv not found. Skipping...
# papara,pf not found. Skipping...
# gollere,sn not found. Skipping...
# sumbawa,id not found. Skipping...
# guanica,us not found. Skipping...
# saryshagan,kz not found. Skipping...
# karamea,nz not found. Skipping...
# yingzhong,cn not found. Skipping...
# 682

# %%
import pandas as pd

cities_df = pd.DataFrame(weather_list)
cities_df
# Out:
#                         City Country      Lat       Lng  Max Temp (F)  \
# 0             Saint-Philippe      RE -21.3585   55.7679         63.99
# 1                     Panabá      MX  21.2833  -88.2667         79.56
# 2                       Mayo      CA  63.5927 -135.8998         39.70
# 3           North Battleford      CA  52.7834 -108.2847         49.41
# 4                    Ushuaia      AR -54.8000  -68.3000         40.66
# ..                       ...     ...      ...       ...           ...
# 677                  Kashgar      CN  39.4547   75.9797         78.08
# 678                    Rundu      NA -17.9333   19.7667         71.33
# 679                 Imbituba      BR -28.2400  -48.6703         69.69
# 680            Saint-Georges      GF   3.9000  -51.8000         73.13
# 681  Sítio Novo do Tocantins      BR  -5.5183  -47.4611         80.74
#
#      Humidity (%)  Cloudiness (%)  Wind Speed (mph)      Current Description
# 0              80              43             12.77               light rain
# 1              74              55              7.65            broken clouds
# 2              71              39              1.97         scattered clouds
# 3              55              29              8.48               light rain
# 4              75              75             23.02  light intensity drizzle
# ..            ...             ...               ...                      ...
# 677            16               0              2.24                clear sky
# 678            29              30              4.70         scattered clouds
# 679            97             100             13.62          overcast clouds
# 680            95              84              2.06            broken clouds
# 681            55              18              4.18               few clouds
#
# [682 rows x 9 columns]

# %%
cities_df.to_csv('WeatherPy_Database.csv')
